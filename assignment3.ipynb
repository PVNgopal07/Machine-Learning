# %% [markdown]
# <a href="https://colab.research.google.com/github/PVNgopal07/Machine-Learning/blob/main/assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #1. Basic Line Plot

# %% [markdown]
# ##a) Plot a simple line graph of 𝑦 = 𝑥2 for 𝑥 values ranging from -10 to 10.

# %%
x = np.linspace(-10, 10, 400)
y = x**2

plt.plot(x, y) #used to plot the x,y values
plt.xlabel("x") #lable
plt.ylabel("y = x^2")  #lable
plt.title("Line Plot of y = x^2")
plt.grid(True) #used to present in a grid view
plt.show()

# %% [markdown]
# ##b) Label the x-axis as "X Values" and the y-axis as "Squared Values."

# %%
plt.xlabel("X Values") #to label x-axis
plt.ylabel("Squared Values") # to label y-axis
plt.plot(x, y)
plt.show()

# %% [markdown]
# ##c) Add a title to the graph.

# %% [markdown]
# #2. Bar Plot

# %% [markdown]
# ##a) Create a bar chart showing the marks scored by 5 students: [Sai, 'Vamsi',
# 'Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88].

# %%
students = ['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita']
marks = [85, 90, 78, 92, 88]

plt.bar(students, marks, color='skyblue')

plt.title("Marks Scored by Students")  #title
plt.show()

# %% [markdown]
# ##b) Add labels to the x-axis and y-axis and give the chart a title.

# %%
plt.xlabel("Students")  #lable
plt.ylabel("Marks")  #lable
plt.bar(students, marks, color='skyblue')
plt.show()

# %% [markdown]
# #3. Scatter Plot

# %% [markdown]
# ##a) Generate two lists of 20 random integers each (for x and y coordinates).

# %%
x = np.random.randint(0, 100, 20)  #ranndom vlues
y = np.random.randint(0, 100, 20)  #ranndom vlues

print("x-coordinates:", x)
print("y-coordinates:", y)
# Out:
# x-coordinates: [68 27 28 87 35  9 93 72 93 25 41 17  5 61 31 80 33 90  1 95]
# y-coordinates: [49  4 15 11 50 72 11 72 62 99 68 25 65 31 10 10 75 26 15 32]

# %% [markdown]
# ##b) Create a scatter plot with these values, and customize it by adding color, size, and labels to the points.

# %%
x = np.random.randint(0, 100, 20)  #ranndom vlues
y = np.random.randint(0, 100, 20)  #ranndom vlues
plt.figure(figsize=(8, 6))
plt.scatter(x, y, label='Data Points', color='green',) #scatter plot


plt.xlabel("X-axis")  #label
plt.ylabel("Y-axis")  #label
plt.title("Scatter Plot with Customization")

plt.legend() #legend

plt.show()  #to show the plot

# %% [markdown]
# #4. Histogram

# %% [markdown]
# ##a) Simulate 100 random values from a normal distribution using np.random.randn() and plot a histogram.

# %%
data = np.random.randn(100)  #random values


plt.hist(data, bins=10, edgecolor='black', color='orange')  # values to specify histogram
plt.xlabel('Value')  #label
plt.ylabel('Frequency')  #label
plt.title('Histogram of 100 Random Values from a Normal Distribution')  #title
plt.show()

# %% [markdown]
# ##b) Customize the number of bins and add a grid to the plot.

# %%
plt.hist(data, bins=20, edgecolor='black', color='orange')
plt.xlabel('Value') #label
plt.ylabel('Frequency')  #label
plt.title('Histogram of 100 Random Values from a Normal Distribution')  #title
plt.grid(True)  #applied grid view to the histogram
plt.show()

# %% [markdown]
# #5. Pie Chart

# %% [markdown]
# ##a) Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E'] with values [20, 30, 25, 15, 10].

# %%
categories = ['A', 'B', 'C', 'D', 'E']  #categories
values = [20, 30, 25, 15, 10]  #values

plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightblue'])  # to specify the pie chart
plt.title('Percentage Distribution of Categories') #title
plt.axis('equal') #axis
plt.show()

# %% [markdown]
# ##b) Display the percentage values on the chart and use a color palette for differentiation.

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [20, 30, 25, 15, 10]

plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightblue'])  # to specify the pie chart
plt.title('Percentage Distribution of Categories')  #title
plt.axis('equal')
plt.show()

# %% [markdown]
# #6. Box Plot (Seaborn)

# %% [markdown]
# ##a) Create a box plot to visualize the distribution of the marks scored by students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73].

# %%
marks = [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]

plt.figure(figsize=(8, 6))  # adjusting the figure size
sns.boxplot(x=marks)  #creating boxppot
plt.xlabel("Marks")
plt.title("Distribution of Marks Scored by Students")
plt.show()

# %% [markdown]
# ##b) Highlight the median and any outliers.

# %%
marks = [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]

plt.figure(figsize=(8, 6))  ## adjusting the figure size
sns.boxplot(x=marks, showmeans=True, medianprops={"color": "red"}, meanprops={"marker":"o", "markerfacecolor":"blue", "markeredgecolor":"black"})  #creating boxplot and highlighting the median
plt.xlabel("Marks")
plt.title("Distribution of Marks Scored by Students")
plt.show()

# %% [markdown]
# #7. Heatmap (Seaborn)

# %% [markdown]
# ##a) Create a 5x5 matrix with random integers between 1 and 10 using np.random.randint() and visualize it as a heatmap using Seaborn.

# %%
matrix_data = np.random.randint(1, 11, size=(5, 5))

matrix_df = pd.DataFrame(matrix_data)

plt.figure(figsize=(8, 6))  # adjusting the figure size
sns.heatmap(matrix_df, cmap="YlGnBu", linewidths=.5)  #creating heatmap
plt.title("5x5 Matrix Heatmap")
plt.show()

# %% [markdown]
# ##b) Add a color bar and annotate the heatmap with the values.

# %%
data = np.random.randint(1, 10, size=(5, 5))
plt.figure(figsize=(8, 6))  # adjusting the figure size
sns.heatmap(data, annot=True, cmap="YlGnBu", linewidths=.5)  #annotated the heatmap with values
plt.title("Heatmap of a 5x5 Matrix")
plt.show()

# %% [markdown]
# # 8. Comparison of Matplotlib and Seaborn

# %% [markdown]
# ##Generate a pair of plots (bar charts or line plots) using the same data in both Matplotlib and Seaborn. Highlight the differences in the code, syntax, and aesthetics of the two libraries.

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [20, 30, 25, 15, 10]

plt.figure(figsize=(8, 6))  # adjusting the figure size
plt.bar(categories, values, color='skyblue')
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Matplotlib Bar Chart")
plt.show()


plt.figure(figsize=(8, 6))  # adjusting the figure size
sns.barplot(x=categories, y=values, palette="Blues_d")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Seaborn Bar Plot")
plt.show()
# Out:
# <ipython-input-75-73db41cebf07>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="Blues_d")

# %% [markdown]
# #9. Pair Plot (Seaborn)

# %% [markdown]
# ##a) Manually create a small dataset with columns such as 'Age', 'Height', 'Weight' for 10 individuals and visualize the relationships using a pair plot.

# %%
data = {'Age': [25, 30, 22, 28, 35, 27, 29, 31, 24, 33],
        'Height': [170, 175, 165, 180, 178, 172, 179, 182, 168, 185],    # data values
        'Weight': [65, 70, 58, 75, 80, 68, 72, 78, 62, 85]}
df = pd.DataFrame(data)  #data to DataFrame

sns.pairplot(df)
plt.show()

# %% [markdown]
# #10. Save and Style Plots

# %% [markdown]
# ##a) Plot any graph of your choice and save it in both .png and .pdf formats.

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.figure(figsize=(8, 6))  # adjusting the figure size
plt.scatter(x, y, color='darkblue', marker='o', s=50, alpha=0.7, label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Customized Scatter Plot')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)


plt.savefig('scatter_plot.png', dpi=300, bbox_inches='tight')
plt.savefig('scatter_plot.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# ##b) Apply at least one built-in style (e.g., 'ggplot' or 'seaborn-darkgrid') and explain how the style impacts the visualization.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='orange', marker='o', s=50, alpha=0.7, label='Data Points')  # to specify the values for  scatter plot
plt.xlabel('X-axis')  #label
plt.ylabel('Y-axis')  #label
plt.title('Customized Scatter Plot with ggplot Style')  #title
plt.legend()  #legend
plt.grid(True, linestyle='--', alpha=0.5)  #grid view

plt.show()
